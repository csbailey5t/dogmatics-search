# %%
import requests

# %%
url = "http://127.0.0.1:8000/query"

# %%
payload = {
    "text": "What is the kingdom of God",
}

# %%
# Write post to url with payload
response = requests.post(url, json=payload)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'response': "The kingdom of God is the rule of God brought to earth from heaven. It is a divine happening executed with heaven's revelation and power. It is also described as the covenant of grace. The Holy Spirit's role is to make people participants in the history of this covenant, enabling them to experience it firsthand.",
#  'source_nodes': [{'node': {'id_': 'b983daac-9247-4884-9742-6ff2b1f42973',
#     'embedding': [-0.00199533557,
#      0.00526444,
#      0.0765531436,
#      0.0116085839,
#      -0.0608021617,
#      0.0328851081,
#      -0.0386999846,
#      0.0464907922,
#      -0.0236546956,
#      0.00930803735,
#      0.0279170573,
#      -0.00795311481,
#      0.0420026071,
#      -0.00321088498,
#      -0.0102466037,
#      0.0598988831,
#      0.0514870696,
#      0.0114109907,
#      0.0671815947,
#      0.0622135401,
#      -0.000710981665,
#      0.0190253761,
#      0.0272113681,
#      0.046603702,
#      -0.0750853121,
#      0.00834830105,
# ...
